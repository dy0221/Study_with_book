# %%
import sys, os
# 현재 파일(.ipynb)의 디렉토리 기준으로 부모 디렉토리를 sys.path에 추가
# os.getcwd()  # 현재 작업 디렉토리 가져오기
sys.path.append(os.path.dirname(os.path.abspath(os.getcwd())))

# %%
import pandas as pd

df_warn = pd.read_csv('..\\data\\남산도서관 장서 대출목록 (2021년 04월).csv', encoding='EUC-KR')
# Out:
# C:\Users\wjm25\AppData\Local\Temp\ipykernel_4816\1602202706.py:3: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_warn = pd.read_csv('..\\data\\남산도서관 장서 대출목록 (2021년 04월).csv', encoding='EUC-KR')

# %%
import pandas as pd

df = pd.read_csv('..\\data\\남산도서관 장서 대출목록 (2021년 04월).csv', encoding='EUC-KR', 
                 dtype={'ISBN': str, '세트 ISBN': str, '주제분류번호': str})
df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
df.tail()
# Out:
#             번호           도서명          저자    출판사  발행년도           ISBN  \
# 401677  401678       韓國現代詩大系      채만묵 編著  한국문화사  1996  9788977352971
# 401678  401679         뉴 웨이브  제임스 모나코 지음    한나래  1996  9788985367448
# 401679  401680  (최인훈 장편소설)화두      최인훈 지음    민음사  1994  9788937401596
# 401680  401681  독일 문학과 세계 문학      吳漢鎭 編著     벽호  1995  9788947700368
# 401681  401682    참으로 소중한 생각      김일상 지음    동문사  1995  9788970610092
#
#               세트 ISBN 부가기호  권   주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 401677  9788977352988  NaN  3  811.608     1     0  1970-01-01          NaN
# 401678  9788985367424  NaN  2   688.04     1     0  1970-01-01          NaN
# 401679  9788937401589  NaN  2    813.6     1     0  1970-01-01          NaN
# 401680  9788947700405  NaN  3   809.05     2     0  1970-01-01          NaN
# 401681  9788970610092    0  1    814.6     0     0  1970-01-01          NaN

# %%
df.to_csv('..\\data\\namsan_04_2021.csv')
